# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score
np.random.seed(42)
mean2, std_deviation2 = 5.5 , 1.5
study_hours = np.round(np.random.normal(mean2,std_deviation2,500),decimals=1)
base_grade = 10
slope = 7
random_noise = np.random.normal(0,10,500)
student_grades = np.round(base_grade + slope *study_hours +random_noise,decimals=1)
student_grades = np.clip(student_grades,0,100)

# %%
data =pd.DataFrame({"student grades": student_grades,"study hours": study_hours})
data.head(50)
# Out:
#     student grades  study hours
# 0             62.7          6.2
# 1             66.2          5.3
# 2             41.5          6.5
# 3             70.2          7.8
# 4             39.2          5.1
# 5             40.8          5.1
# 6             59.4          7.9
# 7             48.3          6.7
# 8             44.1          4.8
# 9             45.8          6.3
# 10            46.3          4.8
# 11            43.1          4.8
# 12            48.9          5.9
# 13            19.1          2.6
# 14            24.5          2.9
# 15            50.5          4.7
# 16            43.0          4.0
# 17            42.2          6.0
# 18            39.7          4.1
# 19            41.3          3.4
# 20            47.2          7.7
# 21            51.8          5.2
# 22            42.6          5.6
# 23            39.5          3.4
# 24            35.3          4.7
# 25            31.9          5.7
# 26            20.3          3.8
# 27            53.2          6.1
# ...

# %%
plt.figure(figsize=(13,13))
plt.scatter(y=student_grades,x=study_hours,color='red')
slope,intercept = np.polyfit(study_hours,student_grades,1)
fitted_line = slope*study_hours +intercept
plt.plot(study_hours,fitted_line,color='green')
plt.xticks(np.arange(0,max(study_hours),step=1))
plt.yticks(np.arange(0,max(student_grades),step=10))
plt.title('The correlation between student grades and their hours of study time')
plt.xlabel('Study Hours')
plt.ylabel('Student Grades')
plt.show()

# %%
prediction = int(input("How many hours have you studied for the exam?"))
value = np.round(np.clip(slope*prediction+ intercept,0,100))
print(f"Your predicted grade is {value}")
# Out:
# Your predicted grade is 71.0

# %%
entry= 7
value2 = np.round(np.clip(slope*entry+ intercept,0,100))
print(value2)
# Out:
# 59.0

# %%
#model accuracy
actual_grades = np.array([19,37,70,42,43,66,8,62])
predicted_grades = np.array([30,46,64,51,39,48,35,59])
r2 = r2_score(actual_grades, predicted_grades)
percentage = r2*100
print(percentage)
# Out:
# 59.57608420443448
